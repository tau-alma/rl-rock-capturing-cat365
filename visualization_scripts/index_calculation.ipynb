# %%
import numpy as np
import pandas as pd

# %%
# human evaluation rewards 1
rewards =[79.00793285879278,
419.4108456770922,
-362.7174000432685,
-197.4575371179974,
398.407652702375,
-282.458523403508,
439.4980121742668
-292.69256021228676,
390.0357523005305,          
-327.74358451505594]         

mean = np.mean(rewards)
std = np.std(rewards)

print(f"Mean ± Std: {mean:.2f} ± {std:.2f}")
# Out:
# Mean ± Std: 29.25 ± 309.95

# %%
# human evaluation rewards 2
rewards =[-324.73414866798896,
139.11046506281414,
849.131800209181,
-384.5558117917529,
-117.26528585163457,
-243.84884806222814,
-144.4783489248215,
-108.9876576922108,
1247.714620841908,
346.91935797228433]


mean = np.mean(rewards)
std = np.std(rewards)

print(f"Mean ± Std: {mean:.2f} ± {std:.2f}")
# Out:
# Mean ± Std: 125.90 ± 511.69

# %%
# human evaluation rewards total
rewards =[79.00793285879278,
419.4108456770922,
-362.7174000432685,
-197.4575371179974,
398.407652702375,
-282.458523403508,
439.4980121742668
-292.69256021228676,
390.0357523005305,          
-327.74358451505594,
-324.73414866798896,
139.11046506281414,
849.131800209181,
-384.5558117917529,
-117.26528585163457,
-243.84884806222814,
-144.4783489248215,
-108.9876576922108,
1247.714620841908,
346.91935797228433]


mean = np.mean(rewards)
std = np.std(rewards)

print(f"Mean ± Std: {mean:.2f} ± {std:.2f}")
# Out:
# Mean ± Std: 80.12 ± 430.86

# %%
# Training conditions
import pandas as pd

path = "/home/mm/For_Amirmasoud/rl-rock-capturing-cat365/results/excavator365-RockCapturing/hp_lr_0.0003-batch_size_128-epochs_4-entropy_coef_0.0003-update_interval_1024-/2026-01-08_15-55-55/model_log/eval/0.monitor.csv"

# Monitor files often start with a JSON metadata line prefixed by '#', so we skip comment lines.
df = pd.read_csv(path, comment="#")

first_col_name = df.columns[0]
first_col = df[first_col_name]

print("First column name:", first_col_name)
print("First 10 values:")
print(first_col.head(10).to_string(index=False))

# If you want it as a Python list:
first_col_list = first_col.tolist()
rewards = first_col_list

mean = np.mean(rewards)
std = np.std(rewards)

print(f"Mean ± Std: {mean:.2f} ± {std:.2f}")
# Out:
# First column name: r
# First 10 values:
# -517.072652
# 1490.382116
# -311.254541
# 1821.478765
# 1817.611456
# 1606.758613
# 1328.066777
# 1309.511675
# 1787.343323
# -156.531860
# Mean ± Std: 1153.38 ± 803.02

# %%
# Rock Test conditions

path = "/home/mm/For_Amirmasoud/rl-rock-capturing-cat365/results/excavator365-RockCapturing/hp_lr_0.0003-batch_size_128-epochs_4-entropy_coef_0.0003-update_interval_1024-/2026-01-09_13-29-55/model_log/eval/0.monitor.csv"

# Monitor files often start with a JSON metadata line prefixed by '#', so we skip comment lines.
df = pd.read_csv(path, comment="#")

first_col_name = df.columns[0]
first_col = df[first_col_name]

print("First column name:", first_col_name)
print("First 10 values:")
print(first_col.head(10).to_string(index=False))

# If you want it as a Python list:
first_col_list = first_col.tolist()
rewards = first_col_list

mean = np.mean(rewards)
std = np.std(rewards)

print(f"Mean ± Std: {mean:.2f} ± {std:.2f}")
# Out:
# First column name: r
# First 10 values:
# 1533.484098
# 1509.305121
# -343.830435
# 1810.453037
# 1818.769302
# 1531.094802
# 1325.570782
# 1253.907235
# -186.904949
# 1694.452152
# Mean ± Std: 1141.24 ± 830.45

# %%
# Soil Test conditions

path = "/home/mm/For_Amirmasoud/rl-rock-capturing-cat365/results/excavator365-RockCapturing/hp_lr_0.0003-batch_size_128-epochs_4-entropy_coef_0.0003-update_interval_1024-/2026-01-09_12-04-53/model_log/eval/0.monitor.csv"

# Monitor files often start with a JSON metadata line prefixed by '#', so we skip comment lines.
df = pd.read_csv(path, comment="#")

first_col_name = df.columns[0]
first_col = df[first_col_name]

print("First column name:", first_col_name)
print("First 10 values:")
print(first_col.head(10).to_string(index=False))

# If you want it as a Python list:
first_col_list = first_col.tolist()
rewards = first_col_list

mean = np.mean(rewards)
std = np.std(rewards)

print(f"Mean ± Std: {mean:.2f} ± {std:.2f}")
# Out:
# First column name: r
# First 10 values:
# -136.269125
# 1500.316939
# -202.710313
# 1831.382517
# 1797.199771
# -409.917905
# 1339.020348
# 1317.077611
# 1777.293966
# 1663.650669
# Mean ± Std: 960.83 ± 919.01
