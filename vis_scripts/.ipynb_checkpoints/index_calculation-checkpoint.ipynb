# %%
import numpy as np

rewards = [
    -410.82816,
    1812.3755,
    1839.2415,
    -464.06274,
    -343.53784,
    1155.1982,
    1481.5,
    -383.89233,
    1294.9866,
    1835.9824
]

mean = np.mean(rewards)
std = np.std(rewards)

print(f"Mean ± Std: {mean:.2f} ± {std:.2f}")
# Out:
# Mean ± Std: 781.70 ± 989.13

# %%
rewards =[1675.228975,
1628.68884,
1701.571048,
1331.156318,
1596.684518,
1265.093478,
1592.629707,
-229.593858,
1701.437653,
-304.516792]

mean = np.mean(rewards)
std = np.std(rewards)

print(f"Mean ± Std: {mean:.2f} ± {std:.2f}")
# Out:
# Mean ± Std: 1195.84 ± 745.17

# %%
rewards =[1473.505758,
-350.427066,
1482.347787,
1605.104074,
-154.51513,
-131.045738,
1182.093831,
1704.554364,
1517.847199,
1190.930734]

mean = np.mean(rewards)
std = np.std(rewards)

print(f"Mean ± Std: {mean:.2f} ± {std:.2f}")
# Out:
# Mean ± Std: 952.04 ± 779.10

# %%
# Saku
rewards =[79.00793285879278,
419.4108456770922,
-362.7174000432685,
-197.4575371179974,
398.407652702375,
-282.458523403508,
439.4980121742668
-292.69256021228676,
390.0357523005305,          
-327.74358451505594]         

mean = np.mean(rewards)
std = np.std(rewards)

print(f"Mean ± Std: {mean:.2f} ± {std:.2f}")
# Out:
# Mean ± Std: 29.25 ± 309.95

# %%
# Joonas
rewards =[-324.73414866798896,
139.11046506281414,
849.131800209181,
-384.5558117917529,
-117.26528585163457,
-243.84884806222814,
-144.4783489248215,
-108.9876576922108,
1247.714620841908,
346.91935797228433]


mean = np.mean(rewards)
std = np.std(rewards)

print(f"Mean ± Std: {mean:.2f} ± {std:.2f}")
# Out:
# Mean ± Std: 125.90 ± 511.69
